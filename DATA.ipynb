# %%
AIzaSyDJrji4oB3A4_Cv_ONRt_wRrdfpjpzs6eI

# %%
import pandas as pd
import googleapiclient.discovery

# %%
channel_id=['UCNU_lfiiWBdtULKOw6X0Dig','UC61Y04JVLkByFRv1K3V-KGQ','UCCzbGDlhrWiroIzUPheGHBw','UCFWCFYvqnAMT-jcCqTp_SlA','UCGc-2PbLX8ZSby2GajcO0uw','UC59K-uG2A5ogwIrHw4bmlEg','UCJskGeByzRRSvmOyZOz61ig','UCtYLUTtgS3k1Fg4y5tAhLbw','UCmEkDZh0HvwHUOcQyxzmAWA','UCTpnUrdHj5FgIaZ_4MK5p6g','UCQhpnItclGAUn4NdGGcEyPQ','UCdm_RWfBa9-FIRk5yHFTPbQ','UCnQweeTKKj0gUZeDG1_PDtQ','UC3Qe9c8dZqnjwcDD2vCZBKQ','UCWv7vMbMWH4-V0ZXdmDpPBA','UCVgOWXEyCmRPEVEerK_49Fw','UCAfZfemyTCM-965RZy6QiGA','UCxDQ-198njudeznOXbAxVZQ','UC_fFL5jgoCOrwAVoM_fBYwA','UC7cs8q-gJRlGwj4A8OmCmXg','UC8CmTnoR19lElKS5rOIk84g','UCh9nVJoWXmFb7sLApWGcLPQ',
           'UCeVMnSShP_Iviwkknt83cww','UCpjxg5lzymGTg_DErqHqS5Q','UCe67-otf77xNR2KOKtAtqKw','UC61FZe__TVwVhs0IjjWfPyg','UC8butISFwT-Wl7EV0hUK0BQ','UC0RhatS1pyxInC00YKjjBqQ','UCCTVrRB5KpIiK6V2GGVsR1Q','UCZN-xTV6lFwfJHl6ZId_dOg']

# %%
channel_id_str=','.join(channel_id)

# %%
type(channel_id_str)
# Out:
# str

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDJrji4oB3A4_Cv_ONRt_wRrdfpjpzs6eI"

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)

# %%
request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id_str,
        
    )
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'SVcC_Ix2FaFHG0dfEBPsPQY9AHw', 'pageInfo': {'totalResults': 30, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'OxRT9jCLJlIz5dKi4l-9aIY5Ung', 'id': 'UC_fFL5jgoCOrwAVoM_fBYwA', 'snippet': {'title': 'Alex Lee', 'description': 'Learn Java!\n\n', 'customUrl': '@alexlorenlee', 'publishedAt': '2013-02-17T01:55:26Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/APkrFKb-VUj0Y7yGkMin6rr6SNBcLRPH7Bj_qw6WKcCuyw=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/APkrFKb-VUj0Y7yGkMin6rr6SNBcLRPH7Bj_qw6WKcCuyw=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/APkrFKb-VUj0Y7yGkMin6rr6SNBcLRPH7Bj_qw6WKcCuyw=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Alex Lee', 'description': 'Learn Java!\n\n'}, 'country': 'US'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 
# ...

# %%
def youtubedata(channel_id):
    finaldata=[]
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_id_str,
        
    )
    response = request.execute()
    for i in range(30):
        finalinfo=dict(title_name=response['items'][i]['snippet']['title'],total_view_count=response['items'][i]['statistics']['viewCount'],total_subscriber_count=response['items'][i]['statistics']['subscriberCount'],video_count=response['items'][i]['statistics']['videoCount'],hidden_subscriber_count=response['items'][i]['statistics']['hiddenSubscriberCount'],user_id=response['items'][i]['snippet']['customUrl'],
                       published=response['items'][i]['snippet']['publishedAt'])
        finaldata.append(finalinfo)
    
    return finaldata

# %%
datacombo=youtubedata(channel_id_str)

# %%
df=pd.DataFrame(datacombo)
df
# Out:
#                                 title_name total_view_count  \
# 0                                 Alex Lee         24826121
# 1              StatQuest with Josh Starmer         56329588
# 2                           Data commence                 0
# 3                               Krish Naik         84938433
# 4                            GeeksforGeeks         68591888
# 5                            Shakra Shamim            70593
# 6                    Programming with Mosh        183324625
# 7                               Prep Insta         21286865
# 8                       Software Samsaaram             4033
# 9                         Data Driven Dive            48704
# 10             MLR Institute of Technology           144681
# 11                        Alex The Analyst         26652575
# 12                           CodeWithHarry        666250960
# 13                         Software  Ammai                0
# 14                               kudvenkat        254109266
# ...

# %%
df['published']=df['published'].str[:9]

# %%
df
# Out:
#                                 title_name total_view_count  \
# 0                                 Alex Lee         24826121
# 1              StatQuest with Josh Starmer         56329588
# 2                           Data commence                 0
# 3                               Krish Naik         84938433
# 4                            GeeksforGeeks         68591888
# 5                            Shakra Shamim            70593
# 6                    Programming with Mosh        183324625
# 7                               Prep Insta         21286865
# 8                       Software Samsaaram             4033
# 9                         Data Driven Dive            48704
# 10             MLR Institute of Technology           144681
# 11                        Alex The Analyst         26652575
# 12                           CodeWithHarry        666250960
# 13                         Software  Ammai                0
# 14                               kudvenkat        254109266
# ...

# %%
import openpyxl as xl

# %%
excel_file=pd.ExcelWriter("YoutubeData.xlsx")
df.to_excel(excel_file)
excel_file.save()
